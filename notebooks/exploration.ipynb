# %% [markdown]
# # Turkce Gorsel Arama Exploration
#
# Bu notebook veri seti inceleme, ornek sorgular ve embedding tabanli retrieval denemeleri icin hazirlandi.

# %%
from src.config import ProjectConfig
from src.data_loader import prepare_data
from src.embedder import embed_all_splits
from src.evaluate import evaluate_split

config = ProjectConfig()
config.ensure_directories()

# %%
# Hazirlik asamasi
prepare_data(config)

# %%
# Embedding ve evaluation
embed_all_splits(config)
evaluate_split(config)
